# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
from support_agent.core import get_answer, print_highlighted_json, Metrics

# %%
question1 = "How can I reset my password if I've forgotten it?"
answer, metrics = get_answer(question1)

# %%
print_highlighted_json(json.loads(answer))
# Out:
# {
#     "answer": "To reset a forgotten password, use the \u201cForgot password\u201d link on the sign-in page. Enter the email or username associated with your account, then follow the password reset link sent to that email. If you don\u2019t receive the email, check spam/junk and any email filters. If your account uses phone verification, you may be able to request a reset code by SMS. If none of these work, contact support and provide your account email and any account details to verify ownership.",
#     "actions": [
#         "Go to the sign-in page and click \u201cForgot password\u201d",
#         "Enter the email address or username for the account",
#         "Check your inbox (and spam/junk) for the password reset email and follow the link",
#         "If available, choose SMS reset to receive a code to your phone",
# ...

# %%
print_highlighted_json(metrics)
# Out:
# {
#     "timestamp": 1762110775,
#     "tokens_prompt": 182,
#     "tokens_completion": 218,
#     "total_tokens": 400,
#     "latency_ms": 5010.497570037842,
#     "estimated_cost_usd": 0.00048150000000000005
# }
